# %%
# Code Author:-
# Name: Shivam Gupta
# Net ID: SXG190040
# CS 6350.001 - Big Data Management and Analytics - F20 Assignment 2 (SPARK Through PySpark(Python))

# %%
from pyspark.sql.functions import split
from pyspark.sql import SparkSession
from pyspark.sql.types import ArrayType, StringType
from pyspark import SparkContext, SparkConf
from pyspark.sql.types import IntegerType
from pyspark.sql.functions import udf,array_contains, desc
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
BUSINESSES_DF = sc.textFile("/FileStore/tables/business.csv").map(lambda L2: L2.split("::")).toDF()

BUSINESSES_DF = BUSINESSES_DF.select(BUSINESSES_DF._1.alias('Business_ID'), BUSINESSES_DF._2.alias('Full_Address'), BUSINESSES_DF._3.alias('Categories'))
BUSINESSES_DF = BUSINESSES_DF.dropDuplicates()

# Splitting the CAtegories Names
Categ_User_Def_Func = udf(lambda Li: Li[5:-1].split(", "), ArrayType(StringType(), False))
BUSINESSES_DF = BUSINESSES_DF.withColumn("Categories", Categ_User_Def_Func(BUSINESSES_DF.Categories))
output = BUSINESSES_DF.rdd.flatMap(lambda Cat: [(C, 1) for C in Cat["Categories"]] )
OUTPUT_DataFrame = output.reduceByKey(lambda C1,C2: C1 +C2).toDF()
OUTPUT_DataFrame = OUTPUT_DataFrame.withColumnRenamed("_1", "Category").withColumnRenamed("_2", "Count")
output_FilePath = '/FileStore/tables/Output_Question5.csv'
OUTPUT_DataFrame.repartition(1).write.csv(output_FilePath,header=True)
OUTPUT_DataFrame.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+------------------+-----+
#           Category|Count|
# +------------------+-----+
#         Sandwiches|  460|
#       Fish &amp; Chips|    5|
#            Tanning|   38|
#               Food| 1874|
#       Coffee &amp; Tea|  552|
#       Asian Fusion|  117|
#         Gift Shops|    5|
#        Active Life|  448|
#        Acupuncture|   36|
#                   |  353|
#      Mediterranean|  134|
#         Automotive|  327|
# Convenience Stores|   79|
#        Auto Repair|  160|
#             Tattoo|   48|
#              Books|  255|
#    Music and Video|  255|
#     Local Services|  476|
#             Hotels|  216|
#          Fast Food|  205|
# +------------------+-----+
# only showing top 20 rows
#
# </div>

# %%
display(OUTPUT_DataFrame)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Category</th><th>Count</th></tr></thead><tbody><tr><td>Sandwiches</td><td>460</td></tr><tr><td>Fish & Chips</td><td>5</td></tr><tr><td>Tanning</td><td>38</td></tr><tr><td>Food</td><td>1874</td></tr><tr><td>Coffee & Tea</td><td>552</td></tr><tr><td>Asian Fusion</td><td>117</td></tr><tr><td>Gift Shops</td><td>5</td></tr><tr><td>Active Life</td><td>448</td></tr><tr><td>Acupuncture</td><td>36</td></tr><tr><td></td><td>353</td></tr><tr><td>Mediterranean</td><td>134</td></tr><tr><td>Automotive</td><td>327</td></tr><tr><td>Convenience Stores</td><td>79</td></tr><tr><td>Auto Repair</td><td>160</td></tr><tr><td>Tattoo</td><td>48</td></tr><tr><td>Books</td><td>255</td></tr><tr><td>Music and Video</td><td>255</td></tr><tr><td>Local Services</td><td>476</td></tr><tr><td>Hotels</td><td>216</td></tr><tr><td>Fast Food</td><td>205</td></tr><tr><td>Dry Cleaning & Laundry</td><td>133</td></tr><tr><td>Professional Services</td><td>118</td></tr><tr><td>Internet Cafes</td><td>8</td></tr><tr><td>Bars</td><td>650</td></tr><t
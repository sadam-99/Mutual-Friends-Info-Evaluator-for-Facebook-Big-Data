# %%
# Code Author:-
# Name: Shivam Gupta
# Net ID: SXG190040
# CS 6350.001 - Big Data Management and Analytics - F20 Assignment 2 (SPARK Through PySpark(Python))

# %%
from pyspark.sql.functions import split
from pyspark.sql import SparkSession
from pyspark import SparkContext, SparkConf
from pyspark.sql.types import IntegerType
from pyspark.sql.functions import udf, desc
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
REVIEWS_DF = sc.textFile("/FileStore/tables/review.csv").map(lambda L1: L1.split("::")).toDF()
BUSINESSES_DF = sc.textFile("/FileStore/tables/business.csv").map(lambda L2: L2.split("::")).toDF()

REVIEWS_DF = REVIEWS_DF.select(REVIEWS_DF._1.alias('Review_ID'), REVIEWS_DF._2.alias('User_ID'), REVIEWS_DF._3.alias('Business_ID'), REVIEWS_DF._4.cast("float").alias('Ratings'))

REVIEWS_DF = REVIEWS_DF.select('Business_ID', 'Ratings').groupBy('Business_ID').avg('Ratings').orderBy(desc('avg(Ratings)')).limit(10)

BUSINESSES_DF = BUSINESSES_DF.select(BUSINESSES_DF._1.alias('Business_ID'), BUSINESSES_DF._2.alias('Full_Address'), BUSINESSES_DF._3.alias('categories'))

output = BUSINESSES_DF.join(REVIEWS_DF, REVIEWS_DF.Business_ID == BUSINESSES_DF.Business_ID)

OUTPUT_DataFrame = output.select(REVIEWS_DF.Business_ID, 'Full_Address', 'categories', 'avg(Ratings)').distinct()
output_FilePath = '/FileStore/tables/Output_Ques4.csv'

OUTPUT_DataFrame.repartition(1).write.csv(output_FilePath,header=True)
OUTPUT_DataFrame.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+--------------------+--------------------+--------------------+------------+
#          Business_ID|        Full_Address|          categories|avg(Ratings)|
# +--------------------+--------------------+--------------------+------------+
# oBsbQlzSdK7XozGE6...|200 Lothrop StOak...|List(Doctors, Hos...|         5.0|
# AqzK7Dr-9zMoxBpsZ...|1212 W Springfiel...|List(Middle Schoo...|         5.0|
# pBkkizqn2jsP6GJ-J...|4150 Regents Park...|List(Dentists, He...|         5.0|
# XYsw_9orEYR1T7jRo...|143 Harvard Ave2n...|List(Professional...|         5.0|
# yS8o6eShVkLh_psn6...|400 W Rosemary St...|List(Skin Care, H...|         5.0|
# CJiN7ZzW_iBJue4eb...|1176 E Colorado B...|List(Investing, F...|         5.0|
# ZCELOqe_TRJ3I5ldV...|707 S 16th StLafa...|List(Automotive, ...|         5.0|
# wl0VZ6n9LrMpDGy_J...|103 Carnegie CtrS...|List(Shopping, Co...|         5.0|
# ANQJQELoPU2z_nCgO...|731 Peachtree Str...|List(Religious Or...|         5.0|
# VtLD3XfTT7T9T70UD...|3636 Nobel DrSte ...|List(Real Estate ...|         5.0|
# +--------------------+--------------------+--------------------+------------+
#
# </div>

# %%
display(OUTPUT_DataFrame)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Business_ID</th><th>Full_Address</th><th>categories</th><th>avg(Ratings)</th></tr></thead><tbody><tr><td>oBsbQlzSdK7XozGE6v1F4w</td><td>200 Lothrop StOaklandPittsburgh, PA 15213</td><td>List(Doctors, Hospitals, Health and Medical, Medical Centers)</td><td>5.0</td></tr><tr><td>AqzK7Dr-9zMoxBpsZNlkoA</td><td>1212 W Springfield AveUrbana, IL 61801</td><td>List(Middle Schools & High Schools, Education)</td><td>5.0</td></tr><tr><td>pBkkizqn2jsP6GJ-Jj1Wug</td><td>4150 Regents Park RowSte 230La Jolla, CA 92037</td><td>List(Dentists, Health and Medical)</td><td>5.0</td></tr><tr><td>XYsw_9orEYR1T7jRoG_BJA</td><td>143 Harvard Ave2nd FlClaremont, CA 91711</td><td>List(Professional Services, Lawyers, Divorce and Family Law)</td><td>5.0</td></tr><tr><td>yS8o6eShVkLh_psn6emCTw</td><td>400 W Rosemary StSte 1001Chapel Hill, NC 27516</td><td>List(Skin Care, Hair Removal, Makeup Artists, Beauty and Spas)</td><td>5.0</td></tr><tr><td>CJiN7ZzW_iBJue4ebTm3dw</td><td>1176 E Colorado BlvdPasadenaPasadena, CA 91106</td><td>List(Investing, Financial Services, Shopping, Antiques)</td><td>5.0</td></tr><tr><td>ZCELOqe_TRJ3I5ldVIxalw</td><td>707 S 16th StLafayette, IN 47905</td><td>List(Automotive, Body Shops)</td><td>5.0</td></tr><tr><td>wl0VZ6n9LrMpDGy_J0RJAw</td><td>103 Carnegie CtrSte 300Princeton, NJ 08540</td><td>List(Shopping, Computers, Local Services, IT Services & Computer Repair, Professional Services, Web Design)</td><td>5.0</td></tr><tr><td>ANQJQELoPU2z_nCgO3pOnQ</td><td>731 Peachtree Street NEMidtownAtlanta, GA 30308</td><td>List(Religious Organizations)</td><td>5.0</td></tr><tr><td>VtLD3XfTT7T9T70UD3mfKw</td><td>3636 Nobel DrSte 100University CitySan Diego, CA 92122</td><td>List(Real Estate Services, Home Services, Real Estate)</td><td>5.0</td></tr></tbody></table></div>

# %%
# Code Author:-
# Name: Shivam Gupta
# Net ID: SXG190040
# CS 6350.001 - Big Data Management and Analytics - F20 Assignment 2 (SPARK Through PySpark(Python))

# %%
from pyspark.sql.functions import split
from pyspark.sql import SparkSession
from pyspark import SparkContext, SparkConf
from pyspark.sql.types import IntegerType
from pyspark.sql.functions import udf, desc
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
CONFIG = SparkConf().setMaster("local").setAppName("Business_Review")
# sc = SparkContext(conf=CONFIG)
SPARK_APP = SparkSession(sc)

# Loading the CSV Files
REVIEWS_DF = sc.textFile("/FileStore/tables/review.csv").map(lambda L1: L1.split("::")).toDF()
BUSINESSES_DF = sc.textFile("/FileStore/tables/business.csv").map(lambda L2: L2.split("::")).toDF()

BUSINESSES_DF = BUSINESSES_DF.select(BUSINESSES_DF._1.alias('Business_ID'), BUSINESSES_DF._2.alias('Full_Address'), BUSINESSES_DF._3.alias('Categories'))
REVIEWS_DF = REVIEWS_DF.select(REVIEWS_DF._1.alias('Review_ID'), REVIEWS_DF._2.alias('User_ID'), REVIEWS_DF._3.alias('Business_ID'), REVIEWS_DF._4.alias('Ratings'))

BUSIN_Stanford_DF = BUSINESSES_DF.filter(BUSINESSES_DF.Full_Address.contains('Stanford'))

OUTPUT_DF = REVIEWS_DF.join(BUSIN_Stanford_DF, REVIEWS_DF.Business_ID == BUSIN_Stanford_DF.Business_ID)
OUTPUT_DataFrame = OUTPUT_DF.select('User_ID','Ratings')
output_FilePath = '/FileStore/tables/Output_Ques3.csv'

OUTPUT_DataFrame.repartition(1).write.csv(output_FilePath,header=True)
OUTPUT_DataFrame.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+--------------------+-------+
#              User_ID|Ratings|
# +--------------------+-------+
# -jNMO8Iknmf9CTptX...|    1.0|
# -jNMO8Iknmf9CTptX...|    1.0|
# cJVqHvDLN9g3GE4Vf...|    3.0|
# cJVqHvDLN9g3GE4Vf...|    3.0|
# OBkKevIQ5T9ZmHiB7...|    5.0|
# OBkKevIQ5T9ZmHiB7...|    5.0|
# E-XwUol0CHWfURrVU...|    2.0|
# E-XwUol0CHWfURrVU...|    2.0|
# K0y25oMcc5VKbtdtg...|    3.0|
# K0y25oMcc5VKbtdtg...|    3.0|
# NCFLZQnlQOhcmDK3c...|    4.0|
# NCFLZQnlQOhcmDK3c...|    4.0|
# 8PrxA7LnJujqSyw28...|    5.0|
# 8PrxA7LnJujqSyw28...|    5.0|
# fEmZHZC7KCQcC-62g...|    4.0|
# fEmZHZC7KCQcC-62g...|    4.0|
# gjfcfzrYZ0O1xINHt...|    2.0|
# gjfcfzrYZ0O1xINHt...|    2.0|
# SPr73Cy7Emc4lRTas...|    4.0|
# SPr73Cy7Emc4lRTas...|    4.0|
# +--------------------+-------+
# only showing top 20 rows
#
# </div>

# %%
display(OUTPUT_DataFrame)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>User_ID</th><th>Ratings</th></tr></thead><tbody><tr><td>-jNMO8Iknmf9CTptXq5fbw</td><td>1.0</td></tr><tr><td>-jNMO8Iknmf9CTptXq5fbw</td><td>1.0</td></tr><tr><td>cJVqHvDLN9g3GE4VfxDbZQ</td><td>3.0</td></tr><tr><td>cJVqHvDLN9g3GE4VfxDbZQ</td><td>3.0</td></tr><tr><td>OBkKevIQ5T9ZmHiB7IascQ</td><td>5.0</td></tr><tr><td>OBkKevIQ5T9ZmHiB7IascQ</td><td>5.0</td></tr><tr><td>E-XwUol0CHWfURrVU-5GOw</td><td>2.0</td></tr><tr><td>E-XwUol0CHWfURrVU-5GOw</td><td>2.0</td></tr><tr><td>K0y25oMcc5VKbtdtgQgPLg</td><td>3.0</td></tr><tr><td>K0y25oMcc5VKbtdtgQgPLg</td><td>3.0</td></tr><tr><td>NCFLZQnlQOhcmDK3cAI29g</td><td>4.0</td></tr><tr><td>NCFLZQnlQOhcmDK3cAI29g</td><td>4.0</td></tr><tr><td>8PrxA7LnJujqSyw28N_3cg</td><td>5.0</td></tr><tr><td>8PrxA7LnJujqSyw28N_3cg</td><td>5.0</td></tr><tr><td>fEmZHZC7KCQcC-62giMTdQ</td><td>4.0</td></tr><tr><td>fEmZHZC7KCQcC-62giMTdQ</td><td>4.0</td></tr><tr><td>gjfcfzrYZ0O1xINHtnQKiA</td><td>2.0</td></tr><tr><td>gjfcfzrYZ0O1xINHtnQKiA</td><td>2.0</td></tr><tr><td>SPr73Cy7Emc4lRTasF98RQ</td><td>4.0</td></tr><tr><td>SPr73Cy7Emc4lRTasF98RQ</td><td>4.0</td></tr><tr><td>WJIEdPeGjP35RScfyRr01w</td><td>5.0</td></tr><tr><td>WJIEdPeGjP35RScfyRr01w</td><td>5.0</td></tr><tr><td>T8F0cHy36gnUXRq7M9Ohrw</td><td>5.0</td></tr><tr><td>T8F0cHy36gnUXRq7M9Ohrw</td><td>5.0</td></tr><tr><td>9ln_jGoCgcu99T2W0o6TpQ</td><td>4.0</td></tr><tr><td>9ln_jGoCgcu99T2W0o6TpQ</td><td>4.0</td></tr><tr><td>j4WWYCnWZ7CJYJHrFctNvg</td><td>3.0</td></tr><tr><td>j4WWYCnWZ7CJYJHrFctNvg</td><td>3.0</td></tr><tr><td>VDmAYW1Gr0zWUJvW2v9ZRA</td><td>1.0</td></tr><tr><td>VDmAYW1Gr0zWUJvW2v9ZRA</td><td>1.0</td></tr><tr><td>g94lYUt_-OVpVTPumC8g9A</td><td>2.0</td></tr><tr><td>g94lYUt_-OVpVTPumC8g9A</td><td>2.0</td></tr><tr><td>D96pOQ39yzgoJWObBZ9Wzg</td><td>4.0</td></tr><tr><td>D96pOQ39yzgoJWObBZ9Wzg</td><td>4.0</td></tr><tr><td>NQysyhps0a7MTytWCJiS3g</td><td>4.0</td></tr><tr><td>NQysyhps0a7MTytWCJiS3g</td><td>4.0</td></tr><tr><td>L1on-1WmHICKBUD4e94nzQ</td><td>3.0</td></tr><tr><td>L1on-1WmHICKBUD4e94nzQ</td><td>3.0</td></tr><tr><td>uDt6yeiVdEzv-cQx4Za8GA</td><td>5.0</td></tr><tr><td>uDt6yeiVdEzv-cQx4Za8GA</td><td>5.0</td></tr><tr><td>kDRy_csgrNdkC2S6Lg5ZMw</td><td>5.0</td></tr><tr><td>kDRy_csgrNdkC2S6Lg5ZMw</td><td>5.0</td></tr><tr><td>_-FgDH7CHQgnfw4lYURa8A</td><td>4.0</td></tr><tr><td>_-FgDH7CHQgnfw4lYURa8A</td><td>4.0</td></tr><tr><td>cx6CMeztrzFYAY0gpaC3Mg</td><td>4.0</td></tr><tr><td>cx6CMeztrzFYAY0gpaC3Mg</td><td>4.0</td></tr><tr><td>zQQUDWpgURl3Phz7sgpMVQ</td><td>4.0</td></tr><tr><td>zQQUDWpgURl3Phz7sgpMVQ</td><td>4.0</td></tr><tr><td>oycGFj5UtlTVlRA6tYE4Jg</td><td>2.0</td></tr><tr><td>oycGFj5UtlTVlRA6tYE4Jg</td><td>2.0</td></tr><tr><td>-BigHX_kb_YK2JBgI8efXA</td><td>5.0</td></tr><tr><td>-BigHX_kb_YK2JBgI8efXA</td><td>5.0</td></tr><tr><td>TC5kEUG5z4OGobOXA7H80w</td><td>5.0</td></tr><tr><td>TC5kEUG5z4OGobOXA7H80w</td><td>5.0</td></tr><tr><td>AmQfAvtc-QYmNHcMIt2aDA</td><td>5.0</td></tr><tr><td>AmQfAvtc-QYmNHcMIt2aDA</td><td>5.0</td></tr><tr><td>ANJ-jY5M8k-FKd7kr7x93w</td><td>5.0</td></tr><tr><td>ANJ-jY5M8k-FKd7kr7x93w</td><td>5.0</td></tr><tr><td>hqojrGeufv6qYpN00R-OsA</td><td>4.0</td></tr><tr><td>hqojrGeufv6qYpN00R-OsA</td><td>4.0</td></tr><tr><td>nnbG-XPXHeomn7KtHItmHg</td><td>1.0</td></tr><tr><td>nnbG-XPXHeomn7KtHItmHg</td><td>1.0</td></tr><tr><td>SFBfsySKt-Rb5aBovef78w</td><td>5.0</td></tr><tr><td>SFBfsySKt-Rb5aBovef78w</td><td>5.0</td></tr><tr><td>FHfjAReTovbu0chLv-WGrQ</td><td>5.0</td></tr><tr><td>FHfjAReTovbu0chLv-WGrQ</td><td>5.0</td></tr><tr><td>WDsr8RnPqbceR3s2yZYr3Q</td><td>3.0</td></tr><tr><td>WDsr8RnPqbceR3s2yZYr3Q</td><td>3.0</td></tr><tr><td>RxNQHWWSgOPoOtapxASD7Q</td><td>5.0</td></tr><tr><td>RxNQHWWSgOPoOtapxASD7Q</td><td>5.0</td></tr><tr><td>QLPqCCnxOkKL_X0u1hWKXA</td><td>2.0</td></tr><tr><td>QLPqCCnxOkKL_X0u1hWKXA</td><td>2.0</td></tr><tr><td>vTTMtFyLqyBGzWbho4jTUg</td><td>4.0</td></tr><tr><td>vTTMtFyLqyBGzWbho4jTUg</td><t ...
